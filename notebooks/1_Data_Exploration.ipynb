# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
pd.set_option('display.max_columns', None)


DATA_PATH = '/home/m2l3k/Desktop/BlockchainNode/data/featurized_labeled_data.csv'
try:
    df = pd.read_csv(DATA_PATH)
    print("Dataset loaded successfully!")
    print(f"Shape of the dataset: {df.shape}")
except FileNotFoundError:
    print(f"Error: Data file not found at {DATA_PATH}. Please run the simulation and preprocessing script first.")
# Out:
# Dataset loaded successfully!
# Shape of the dataset: (1423, 25)

# %%
print("--- First 5 Rows ---")
display(df.head())

print("\n--- Data Info ---")
df.info()

print("\n--- Descriptive Statistics ---")
display(df.describe().T)
# Out:
# --- First 5 Rows ---
#    block_index  miner_id  num_tx  time_since_last_block  avg_energy  \
# 0            1         0      12               5.581465    0.007500
# 1            2         1       7               0.500495    0.008571
# 2            3         4       9               0.505226    0.007778
# 3            4         9       8               0.505234    0.008750
# 4            5         9       9               0.551826    0.002000
#
#    std_dev_energy  total_energy  avg_amount  std_dev_amount  total_amount  \
# 0        0.004523         0.090    1.070003        1.951452     12.840037
# 1        0.003780         0.060    0.217755        0.549668      1.524285
# 2        0.004410         0.070    0.801464        1.615447      7.213174
# 3        0.003536         0.070    0.420472        1.160990      3.363774
# 4        0.003000         0.018    0.002000        0.003000      0.018000
#
#    num_deliveries  num_payments  num_theft_attempts  num_alerts  \
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='anomaly_type', data=df, palette='viridis')
plt.title('Distribution of Anomaly Types')
plt.xlabel('Anomaly Type')
plt.ylabel('Number of Blocks')
plt.show()

print("\n--- Anomaly Distribution ---")
print(df['anomaly_type'].value_counts(normalize=True) * 100)
# Out:
# /tmp/ipykernel_7233/2229836174.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='anomaly_type', data=df, palette='viridis')
# --- Anomaly Distribution ---
# anomaly_type
# Normal       83.555868
# Unknown       9.908644
# Tampering     5.411103
# Breakdown     1.124385
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(x='anomaly_type', y='num_tx', data=df, palette='pastel')
plt.title('Number of Transactions by Anomaly Type')
plt.xlabel('Anomaly Type')
plt.ylabel('Number of Transactions per Block')
plt.yscale('log') # Use a log scale if DoS attacks create huge outliers
plt.show()
# Out:
# /tmp/ipykernel_7233/393393245.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='anomaly_type', y='num_tx', data=df, palette='pastel')

# %%
plt.figure(figsize=(14, 7))
sns.violinplot(x='anomaly_type', y='total_energy', data=df, palette='muted')
plt.title('Total Energy Traded by Anomaly Type')
plt.xlabel('Anomaly Type')
plt.ylabel('Total Energy (kWh)')
plt.show()
# Out:
# /tmp/ipykernel_7233/4167792448.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='anomaly_type', y='total_energy', data=df, palette='muted')

# %%
key_features = ['num_tx', 'avg_energy', 'std_dev_energy', 'total_amount', 'anomaly_type']
subset_df = df[key_features]

sns.pairplot(subset_df, hue='anomaly_type', palette='bright', corner=True)
plt.suptitle('Pair Plot of Key Features by Anomaly Type', y=1.02)
plt.show()

# %%
numeric_df = df.select_dtypes(include=np.number)

plt.figure(figsize=(16, 12))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Feature Correlation Heatmap')
plt.show()
